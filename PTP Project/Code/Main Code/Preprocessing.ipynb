# %%
# ------ Load Dataset ---------
# import library
import pandas as pd
import numpy as np

# membaca file csv
TWEET_DATA = pd.read_csv("D:/Kuliah Online/Pemrosesan Teks Praktik/PTP Project/Data/G20Indonesia_Normalization.csv")

# mengganti nama kolom
TWEET_DATA.columns = ['tweet']

# menampilkan data bagian head
TWEET_DATA.head()
# Out:
#                                                tweet
# 0  A dan C Jawaban nya min mainNakerpresidensiGGI...
# 1  Ayo siapa yang takut .. Amerika Rusia Ketemuan...
# 2  Gerakan nasional literasi digital Digital tale...
# 3  Indonesia ... IndonesiaJuara IndonesiaHebatInd...
# 4  Keren bangetMas Memtri dengan Program Merdeka ...

# %%
# ------ Case Folding ---------
# mengubah semua huruf menjadi kecil
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].str.lower()

print('Hasil Case Folding :')
TWEET_DATA.head()
# Out:
# Hasil Case Folding :
#                                                tweet
# 0  a dan c jawaban nya min mainnakerpresidensiggi...
# 1  ayo siapa yang takut .. amerika rusia ketemuan...
# 2  gerakan nasional literasi digital digital tale...
# 3  indonesia ... indonesiajuara indonesiahebatind...
# 4  keren bangetmas memtri dengan program merdeka ...

# %%
# ------ Tokenizing ---------
# import library
import string 
import re # regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# menghapus karakter spesial
def remove_tweet_special(text):
    # menghapus tab, baris baru & back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, dll.)
    text = text.encode('ascii', 'replace').decode('ascii')
    text = re.sub("b'|b\"",'',text)
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_tweet_special)

# menghapus nomor
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_number)

# menghapus tanda baca
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_punctuation)

# menghapus spasi awal & akhir
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_LT)

# menghapus banyak spasi menjadi satu spasi
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_multiple)

# menghapus karakter tunggal
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_singl_char)

# NLTK tokenisasi kata 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['tweet'].apply(word_tokenize_wrapper)

print('Hasil Tokenizing :') 
TWEET_DATA.head()
# Out:
# Hasil Tokenizing :
#                                                tweet  \
# 0   dan  jawaban nya min mainnakerpresidensiggind...
# 1  ayo siapa yang takut amerika rusia ketemuan di...
# 2  gerakan nasional literasi digital digital tale...
# 3  indonesia indonesiajuara indonesiahebatindones...
# 4  keren bangetmas memtri dengan program merdeka ...
#
#                                         tweet_tokens
# 0  [dan, jawaban, nya, min, mainnakerpresidensigg...
# 1  [ayo, siapa, yang, takut, amerika, rusia, kete...
# 2  [gerakan, nasional, literasi, digital, digital...
# 3  [indonesia, indonesiajuara, indonesiahebatindo...
# 4  [keren, bangetmas, memtri, dengan, program, me...

# %%
# ------ Filtering (Stopword Removal) --------- 
from nltk.corpus import stopwords

# ---------------------------- stopword from NLTK stopword -------------------------------------
# stopword indonesia
list_stopwords = stopwords.words('indonesian')

# ---------------------------- menambahkan stopword manual  ------------------------------------
# menambahkan stopword tambahan
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 'si', 'tau', 'tdk', 'tuh', 'utk', 'ya','jd',
                       'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt', 'noh'
                       '&amp', 'yah', 'gk', 'ya', 'mo', 'mah', 'oh', 'bgt', 'ah', 'lg', 'gini', 'gni', 'dll'
                       'hny', 'in', 'gk', 'gin', 'mh', 'ma', 'Pe', 'Sa', 'su', 'in', 'd'])

# --------------------------- menambahkan stopword dari file txt -------------------------------
# membaca file stopword txt menggunakan pandas
txt_stopword = pd.read_csv("D:/Kuliah Online/Pemrosesan Teks Praktik/PTP Project/Resource/stopwordbahasa.txt", names= ["stopwords"], header = None)

# konversi string stopword ke daftar & tambahkan stopword tambahan
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# konversi list ke dictionary
list_stopwords = set(list_stopwords)


# hapus stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal) 

print('Hasil Filtering :') 
TWEET_DATA.head()
# Out:
# Hasil Filtering :
#                                                tweet  \
# 0   dan  jawaban nya min mainnakerpresidensiggind...
# 1  ayo siapa yang takut amerika rusia ketemuan di...
# 2  gerakan nasional literasi digital digital tale...
# 3  indonesia indonesiajuara indonesiahebatindones...
# 4  keren bangetmas memtri dengan program merdeka ...
#
#                                         tweet_tokens  \
# 0  [dan, jawaban, nya, min, mainnakerpresidensigg...
# 1  [ayo, siapa, yang, takut, amerika, rusia, kete...
# 2  [gerakan, nasional, literasi, digital, digital...
# 3  [indonesia, indonesiajuara, indonesiahebatindo...
# 4  [keren, bangetmas, memtri, dengan, program, me...
#
#                                     tweet_tokens_WSW
# 0  [min, mainnakerpresidensiggindonesiaewgindonesia]
# 1  [ayo, takut, amerika, rusia, ketemuan, bali, g...
# 2  [gerakan, nasional, literasi, digital, digital...
# 3  [indonesia, indonesiajuara, indonesiahebatindo...
# 4  [keren, bangetmas, memtri, program, merdeka, b...

# %%
# ------ Stemming --------- 
# import package Sastrawi 
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# membuat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# menerapkan stemmed term ke dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_tokens_WSW'].swifter.apply(get_stemmed_term)

print('Hasil Stemming :') 
TWEET_DATA.head()
# Out:
# 912
# ------------------------
# min : min
# mainnakerpresidensiggindonesiaewgindonesia : mainnakerpresidensiggindonesiaewgindonesia
# ayo : ayo
# takut : takut
# amerika : amerika
# rusia : rusia
# ketemuan : ketemu
# bali : bal
# gindonesia : gindonesia
# hebatnya : hebat
# bu : bu
# da : da
# gerakan : gera
# nasional : nasional
# literasi : literasi
# digital : digital
# talent : talent
# scholarship : scholarship
# leadership : leadership
# academy : academy
# program : program
# kartu : kartu
# prakerjalpsi : prakerjalpsi
# indonesia : indonesia
# indonesiajuara : indonesiajuara
# indonesiahebatindonesiadamai : indonesiahebatindonesiadamai
# keren : keren
# bangetmas : bangetmas
# memtri : memtri
# merdeka : merdeka
# belajarnyagindonesia : belajarnyagindonesia
# presidensiindonesia : presidensiindonesia
# konsumen : konsumen
# industri : industri
# rumah : rumah
# tangga : tangga
# diberdayakan : daya
# koperasi : koperasi
# lapor : lapor
# bisanya : bisa
# cewe : cewe
# bego : bego
# bencong : bencong
# joget : joget
# disuka : suka
# mendingan : mending
# doa : doa
# perang : perang
# yth : yth
# perencana : rencana
# core : core
# values : values
# gindonesiaakan : gindonesiaakan
# keputusan : putus
# diteriakin : diteriakin
# event : event
# ditonton : tonton
# gila : gila
# nari : nari
# pikirin : pikirin
# ancaman : ancam
# lo : lo
# bahas : bahas
# ukraina : ukraina
# formula : formula
# urusan : urus
# bang : bang
# mending : mending
# nonton : nonton
# negara : negara
# besara : besara
# pro : pro
# perdamaian : damai
# kaya : kaya
# org : org
# indo : indo
# mikir : mikir
# kesel : kesel
# gw : gw
# isi : isi
# twitter : twitter
# menetapkan : tetap
# kota : kota
# bandung : bandung
# jawa : jawa
# barat : barat
# lokasi : lokasi
# penyelenggaraan : selenggara
# pertemuan : temu
# kelompok : kelompok
# kerja : kerja
# ngapain : ngapain
# ngurusin : ngurusin
# potensi : potensi
# kekuatan : kuat
# membangun : bangun
# konkret : konkret
# perusahaan : usaha
# serikat : serikat
# berkemban : kemban
# berupaya : upaya
# mewujudkan : wujud
# transformasi : transformasi
# negeri : negeri
# memperjuangkannya : juang
# berlangsungthe : berlangsungthe
# sustainable : sustainable
# finance : finance
# private : private
# sector : sector
# roundtable : roundtable
# xd : xd
# forum : forum
# berdiskusi : diskus
# acara : acara
# jg : jg
# momentum : momentum
# memperkuat : kuat
# promosi : promosi
# produk : produk
# umkm : umkm
# lokal : lokal
# sejalan : jalan
# agenda : agenda
# inklusi : inklusi
# keuangan : uang
# pd : pd
# presidensi : presidensi
# alhamdulillah : alhamdulillah
# presiden : presiden
# elon : elon
# musk : musk
# hadir : hadir
# november : november
# anggota : anggota
# menyerukan : seru
# mungkinhal : mungkinhal
# menkeusmi : menkeusmi
# konferesi : konferesi
# pers : pers
# diada : ada
# women : women
# business : business
# action : action
# council : council
# wibac : wibac
# menggelar : gelar
# bilateral : bilateral
# menteri : menteri
# ukm : ukm
# republik : republik
# rencana : rencana
# renovasi : renovasi
# kubah : kubah
# gedung : gedung
# dpr : dpr
# streaming : streaming
# jam : jam
# kanal : kanal
# youtube : youtube
# bahlil : bahlil
# terbaik : baik
# rangka : rangka
# konsepsi : konsepsi
# gl : gl
# berdasarkan : dasar
# laporan : lapor
# climate : climate
# bonds : bonds
# initiative : initiative
# penerbitan : terbit
# obligasi : obligasi
# hijau : hijau
# green : green
# mencapai : capai
# us : us
# berita : berita
# komitmen : komitmen
# tunisia : tunisia
# membuka : buka
# peningkatan : tingkat
# kerjasama : kerjasama
# bidang : bidang
# ekonomi : ekonomi
# besok : besok
# turnamen : turnamen
# final : final
# arena : arena
# dr : dr
# zomboss : zomboss
# comebackpvz : comebackpvz
# pennyspursuit : pennyspursuit
# bonus : bonus
# demografi : demografi
# kesempatan : sempat
# strategis : strategis
# percepatan : cepat
# pembangunan : bangun
# du : du
# dewg : dewg
# sepakati : sepakat
# isu : isu
# krusial : krusial
# dunia : dunia
# ekosistem : ekosistem
# pendidikan : didik
# bergotong : gotong
# royong : royong
# akselerasi : akselerasi
# seba : seba
# kemendikbudristek : kemendikbudristek
# pulihbersama : pulihbersama
# menciptakan : cipta
# memperluas : luas
# diskusi : diskusi
# menyelenggarakan : selenggara
# kegiatan : giat
# road : road
# to : to
# investment : investment
# topi : topi
# meningkatkan : tingkat
# upaya : upaya
# gabungan : gabung
# mempercepat : cepat
# transisi : transisi
# energi : energi
# mengurangi : kurang
# emisi : emisi
# karbon : karbon
# global : global
# berkualitas : kualitas
# delegasi : delegasi
# atasi : atas
# kesenjangan : senjang
# membahas : bahas
# perangkat : perangkat
# mengukur : ukur
# keterampilan : terampil
# lite : lite
# mengemuka : muka
# nd : nd
# partnership : partnership
# for : for
# financial : financial
# inclusion : inclusion
# plenary : plenary
# meeting : meeting
# diselenggarak : diselenggarak
# dana : dana
# berfungsi : fungsi
# mendukung : dukung
# ketahanan : tahan
# stabilitas : stabilitas
# asobat : asobat
# pantau : pantau
# penduduk : duduk
# usia : usia
# produktif : produktif
# dibanding : banding
# nonproduktif : nonproduktif
# digitalisasi : digitalisasi
# sektor : sektor
# salah : salah
# game : game
# changer : changer
# akibat : akibat
# pandemi : pandemi
# covi : covi
# direktur : direktur
# utama : utama
# sakit : sakit
# pusat : pusat
# infeksi : infeksi
# sulianti : sulianti
# saroso : saroso
# mohammad : mohammad
# syahril : syahril
# resmi : resmi
# juru : juru
# bicara : bicara
# kemenkes : kemenkes
# pencapaian : capai
# diraih : raih
# prioritas : prioritas
# edwg : edwg
# dibahas : bahas
# solidaritas : solidaritas
# dukungan : dukung
# umkmgodigitalgoglobal : umkmgodigitalgoglobal
# pembahasan : bahas
# kki : kki
# mengalami : alami
# covid : covid
# perhat : perhat
# era : era
# berjalan : jalan
# bangga : bangga
# kepala : kepala
# tegak : tegak
# dihadapan : hadap
# bangsa : bangsa
# tertunduk : tunduk
# finalisasi : final
# dokumen : dokumen
# persidangan : sidang
# pergantian : ganti
# perwalian : wali
# anak : anak
# almh : almh
# farahberita : farahberita
# selengkapnya : lengkap
# silahkan : silah
# klik : klik
# link : link
# empower : empower
# gelar : gelar
# yogyakarta : yogyakarta
# dorong : dorong
# kontribusi : kontribusi
# peran : peran
# perempuan : perempuan
# hardiknas : hardiknas
# rutan : rutan
# jeneponto : jeneponto
# upacara : upacara
# bendera : bendera
# peringati : ingat
# baca : baca
# hai : hai
# sohisebagai : sohisebagai
# konferensi : konferensi
# internasional : internasional
# imf : imf
# world : world
# bank : bank
# ktt : ktt
# langsung : langsung
# mendorong : dorong
# perubahan : ubah
# konvensional : konvensional
# teknologi : teknologi
# halo : halo
# sobatkom : sobatkom
# memegang : pegang
# penuh : penuh
# manfaat : manfaat
# pembentukan : bentuk
# bertujuan : tuju
# pertumbuhan : tumbuh
# kuat : kuat
# berkelanjutan : lanjut
# lantas : lantas
# happy : happy
# vesak : vesak
# daypray : daypray
# peace : peace
# and : and
# harmony : harmony
# on : on
# this : this
# auspicious : auspicious
# dayselamat : dayselamat
# raya : raya
# waisak : waisak
# be : be
# muncul : muncul
# kembalipvz : kembalipvz
# gpedia : gpedia
# lapangan : lapang
# peluang : peluang
# untukrewriting : untukrewriting
# ev : ev
# esg : esg
# supply : supply
# chain : chain
# kombinasi : kombinasi
# sumber : sumber
# daya : daya
# alam : alam
# indust : indust
# aspirasi : aspirasi
# ikuti : ikut
# informasi : informasi
# kelanjutan : lanjut
# kunjungan : kunjung
# menko : menko
# luhut : luhut
# binsar : binsar
# pandjaitan : pandjaitan
# dubes : dubes
# rosan : ros
# roeslani : roeslani
# minggu : minggu
# wargi : wargi
# membantu : bantu
# komunitas : komunitas
# menghadapi : hadap
# tantangan : tantang
# pemulihan : pulih
# sosial : sosial
# lewatkan : lewat
# kuliah : kuliah
# aktif : aktif
# deeskalasi : deeskalasi
# konflik : konflik
# rusiaukrain : rusiaukrain
# jokowi : jokowi
# effect : effect
# harga : harga
# sawit : sawit
# rekor : rekor
# tertinggi : tinggi
# minyakgoreng : minyakgoreng
# cpo : cpo
# jubir : jubir
# maudy : maudy
# ayunda : ayunda
# fokus : fokus
# maudyayunda : maudyayunda
# jernihkanharapan : jernihkanharapan
# kompascom : kompascom
# menekankan : tekan
# perluasan : luas
# akses : akses
# kasihan : kasihan
# teman : teman
# sedari : dar
# terlilit : lilit
# karet : karet
# gelang : gelang
# plastik : plastik
# tubuhnya : tubuh
# menyusut : susut
# tertekuk : tekuk
# kawal : kawal
# programkerja : programkerja
# kebaikan : baik
# sayabersamajokowi : sayabersamajokowi
# ht : ht
# keberanian : berani
# tolak : tolak
# intervensi : intervensi
# undang : undang
# sorotan : sorot
# media : media
# produktivitas : produktivitas
# saing : saing
# berbasis : bas
# gotong : gotong
# kominfo : kominfo
# sidang : sidang
# saj : saj
# umumperan : umumperan
# rusiaukraina : rusiaukraina
# inaugurasi : inaugurasi
# ind : ind
# lemhanas : lemhanas
# siapkan : siap
# skenario : skenario
# main : main
# tebaktebakan : tebaktebakan
# yuk : yuk
# rekanaker : rekanaker
# employment : employment
# working : working
# group : group
# ewg : ewg
# gindon : gindon
# mangrove : mangrove
# forest : forest
# area : area
# tahura : tahura
# ngurah : ngurah
# rai : rai
# telaga : telaga
# waja : waja
# benoa : benoa
# bay : bay
# nusa : nusa
# recovertogetherrecoverstronger : recovertogetherrecoverstronger
# mantuul : mantuul
# makanan : makan
# dihidangkan : hidang
# menarik : tarik
# paduan : padu
# warna : warna
# mengundang : undang
# perhatian : perhati
# mari : mari
# dukung : dukung
# menjadikan : jadi
# katalisator : katalisator
# ek : ek
# yamaka : yamaka
# topik : topik
# terobosan : terobos
# belajar : ajar
# pembelajaran : ajar
# menghadirkan : hadir
# kuriku : kur
# melanjutkan : lanjut
# perdana : perdana
# education : education
# maret : maret
# mendikbud : mendikbud
# ristek : ristek
# nadiem : nadiem
# makarim : makarim
# memperkenalkan : kenal
# negaranegara : negaranegara
# mendikbudristek : mendikbudristek
# menindaklanjuti : menindaklanjuti
# st : st
# edmcswg : edmcswg
# dilaksanakan : laksana
# jakarta : jakarta
# tang : tang
# menkominfo : menkominfo
# johnny : johnny
# plate : plate
# pemerintah : perintah
# berkoordinasi : koordinasi
# partner : partner
# globa : globa
# berharap : harap
# menghasilkan : hasil
# kesepakatan : sepakat
# memiliki : milik
# lancar : lancar
# pemahaman : paham
# meleng : meleng
# menparekraf : menparekraf
# berpesan : pesan
# kedepannya : depan
# berkolaborasi : kolaborasi
# pariwisata : pariwisata
# mengedepa : depa
# sri : sri
# mulyani : mulyani
# ministers : ministers
# central : central
# governors : governors
# fmcbg : fmcbg
# komunikasi : komunikasi
# informatika : informatika
# menyambut : sambut
# coba : coba
# tulis : tulis
# harapanmu : harap
# kolom : kolom
# komentar : komentar
# xgindonesia : xgindonesia
# narahubung : narahubung
# makincakapdigital : makincakapdigital
# cfdsbagiilmu : cfdsbagiilmu
# eventmahasiswa : eventmahasiswa
# eventjogja : eventjogja
# eventonline : eventonline
# bekerjasama : bekerjasama
# sinarmas : sinarmas
# land : land
# mengadakan : ada
# side : side
# temaac : temaac
# one : one
# empowerment : empowerment
# ogwe : ogwe
# platform : platform
# dirancang : rancang
# pengusaha : usaha
# didu : didu
# prakarsa : prakarsa
# memandang : pandang
# perlindungan : lindung
# adaptif : adaptif
# pekerja : kerja
# informal : informal
# diperluas : luas
# penin : tin
# seminar : seminar
# gindonesi : gindonesi
# pelaksanaannya : laksana
# mengoordinasikan : koordinasi
# isuisu : isuisu
# sherpa : sherpa
# track : track
# berperan : peran
# mem : mem
# menurunkan : turun
# beli : beli
# masyarakat : masyarakat
# pasalnya : pasal
# interaksi : interaksi
# ruangan : ruang
# pasar : pasar
# ekologi : ekologi
# argowijil : argowijil
# tradisional : tradisional
# prinsip : prinsip
# pengendalian : kendali
# pertambangan : tambang
# diharapkan : harap
# political : political
# declaration : declaration
# tingkat : tingkat
# mente : mente
# ekologis : ekologis
# diinisiasi : inisiasi
# memulihkan : pulih
# bekas : bekas
# tambang : tambang
# pemerataan : perata
# dinegara : negara
# kepulauangindonesia : kepulauangindonesia
# dorongnkrilebihmaju : dorongnkrilebihmaju
# aksesibilitas : aksesibilitas
# kepulauanpemerataan : kepulauanpemerataan
# aks : aks
# penggunaan : guna
# kendaraan : kendara
# listrik : listrik
# strategi : strategi
# target : target
# fo : fo
# permohonan : mohon
# relokasi : relokasi
# ketiga : tiga
# farah : farah
# rasyid : rasyid
# munif : munif
# tanah : tanah
# air : air
# inisiatif : inisiatif
# berfokus : fokus
# universal : universal
# digi : digi
# kajiankajian : kajiankajian
# cswg : cswg
# masukan : masuk
# saran : saran
# economy : economy
# diselenggarakan : selenggara
# mei : mei
# pertem : tem
# kap : kap
# mendasari : dasar
# labuan : labu
# bajo : bajo
# juli : juli
# peserta : serta
# diajak : ajak
# menikmati : nikmat
# makan : makan
# malam : malam
# pertunjukan : tunjuk
# sendratari : sendratari
# latar : latar
# belak : belak
# planet : planet
# layak : layak
# huni : huni
# smua : smua
# manusia : manusia
# pandang : pandang
# status : status
# praktek : praktek
# hunian : huni
# terjangkaugindonesia : terjangkaugindonesia
# uindonesia : uindonesia
# joko : joko
# widodo : widodo
# berkomunikasi : komunikasi
# via : via
# saluran : salur
# telepon : telepon
# vladimir : vladimir
# putin : putin
# terkait : kait
# komun : komun
# bertolak : tolak
# jadwal : jadwal
# pernyata : nyata
# tegaskan : tegas
# implementasi : implementasi
# investasi : investasi
# bertemu : temu
# chairman : chairman
# ceo : ceo
# products : products
# seif : seif
# iriana : iriana
# washington : washington
# dcyoutube : dcyoutube
# pusaka : pusaka
# pembiayaan : biaya
# kesenj : kesenj
# usulkan : usul
# ukuran : ukur
# infrastruktur : infrastruktur
# pember : pember
# berkembang : kembang
# least : least
# developing : developing
# countries : countries
# proporsi : proporsi
# terbarukan : baru
# ebt : ebt
# pembangkit : bangkit
# berkisar : kisar
# tertingg : tertingg
# rabu : rabu
# didampingi : damping
# chair : chair
# alternate : alternate
# konferen : konferen
# pe : pe
# tahanan : tahan
# kelas : kelas
# iimajene : iimajene
# mengucapkanselamat : mengucapkanselamat
# memperingati : ingat
# pimpin : pimpin
# sabilulungan : sabilulungan
# filosofi : filosofi
# sunda : sunda
# lekat : lekat
# alasan : alas
# dipilihnya : pilih
# pert : pert
# sahabatdikbud : sahabatdikbud
# sbg : sbg
# pengg : pengg
# kemendik : dik
# kemendikbudrist : kemendikbudrist
# daerah : daerah
# gugusan : gugus
# vulkaniknya : vulkaniknya
# gunung : gunung
# berapi : rap
# diterapkan : terap
# gelaran : gelar
# rama : rama
# pengampu : ampu
# trade : trade
# industry : industry
# tiiwg : tiiwg
# kementerian : menteri
# bkpm : bkpm
# insinyur : insinyur
# mengagumi : kagum
# langka : langka
# khusus : khusus
# as : as
# joe : joe
# biden : biden
# menghadiri : hadir
# kemendikbud : kemendikbud
# menginisiasi : inisiasi
# memperbarui : baru
# unit : unit
# selamat : selamat
# temankeu : temankeu
# xpertemuan : xpertemuan
# berlangs : berlangs
# temankeuberikut : temankeuberikut
# kebangkitan : bangkit
# harkitnas : harkitnas
# inidiplomasi : inidiplomasi
# indonesianway : indonesianway
# indone : indone
# selaras : selaras
# tujuan : tuju
# meninggalkan : tinggal
# warisan : waris
# nyata : nyata
# tahan : tahan
# semoga : moga
# membawa : bawa
# pemimpin : pimpin
# elektrifikasi : elektrifikasi
# kehidupan : hidup
# ikli : ikli
# bantuan : bantu
# bcg : bcg
# boston : boston
# consulting : consulting
# disiapkan : siap
# non : non
# panduan : pandu
# pembaha : pembaha
# sobatrupiah : sobatrupiah
# bi : bi
# sistem : sistem
# pembayaran : bayar
# antarnegara : antarnegara
# hmmm : hmmm
# talk : talk
# show : show
# safeguarding : safeguarding
# naturetalk : naturetalk
# ii : ii
# promoting : promoting
# circular : circular
# economyyuk : economyyuk
# daftarkan : daftar
# dirimu : diri
# lin : lin
# ber : ber
# kontributor : kontributor
# iklim : iklim
# dominan : dominan
# menyumbang : sumbang
# hubungan : hubung
# lpsindonesia : lpsindonesia
# amanadalps : amanadalps
# lpsamanadat : lpsamanadat
# sa : sa
# terpilih : pilih
# memaparkan : papar
# tertarik : tarik
# seputar : putar
# saksikan : saksi
# igital : igital
# transf : transf
# perkembangan : kembang
# terkini : kini
# pelaksanaan : laksana
# timmarves : timmarves
# kunjungi : kunjung
# mempromosikan : promosi
# co : co
# collect : collect
# diangkat : angkat
# foru : foru
# wawasan : wawas
# usaha : usaha
# menengah : tengah
# mengidentifi : mengidentifi
# terdampak : dampak
# mene : mene
# menetapk : menetapk
# update : update
# thailand : thailand
# orang : orang
# sembuh : sembuh
# unjuk : unjuk
# diikuti : ikut
# ribuan : ribu
# tergabung : gabung
# freeport : freeport
# menandai : tanda
# aksi : aksi
# mogok : mogok
# kerangka : kerangka
# berdampak : dampak
# peni : peni
# peningkat : tingkat
# versi : versi
# budaya : budaya
# nihh : nihh
# numpang : numpang
# rame : rame
# thailandopen : thailandopen
# wayang : wayang
# polisi : polisi
# sispreneur : sispreneur
# inkubasi : inkubasi
# milik : milik
# xl : xl
# axiata : axiata
# pengge : pengge
# bergabung : gabung
# development : development
# dwg : dwg
# temamemperkuat : temamemperkuat
# sain : sain
# umk : umk
# mengikuti : ikut
# diadakan : ada
# tema : tema
# temarebu : temarebu
# sahabatbahari : sahabatbahari
# kenalkan : kenal
# kuliner : kuliner
# gkkp : gkkp
# kkpaccele : kkpaccele
# simak : simak
# video : video
# moneter : moneter
# fundamental : fundamental
# berlaku : laku
# barang : barang
# publik : publik
# menjaga : jaga
# uratas : uratas
# pencerahan : cerah
# agama : agama
# islam : islam
# menyejukan : sejuk
# mencerdaskan : cerdas
# inklusif : inklusif
# aaamiiin : aaamiiin
# llohumma : llohumma
# ndonesiamaju : ndonesiamaju
# kamibersamajokowi : kamibersamajokowi
# jokowidodo : jokowidodo
# indonesiamaju : indonesiamaju
# meja : meja
# keuanganvideo : keuanganvideo
# belajartanpabataskitapemelajarumkm : belajartanpabataskitapemelajarumkm
# belajartanpabataskitapemelajarumkmgindonesia : belajartanpabataskitapemelajarumkmgindonesia
# {'min': 'min', 'mainnakerpresidensiggindonesiaewgindonesia': 'mainnakerpresidensiggindonesiaewgindonesia', 'ayo': 'ayo', 'takut': 'takut', 'amerika': 'amerika', 'rusia': 'rusia', 'ketemuan': 'ketemu', 'bali': 'bal', 'gindonesia': 'gindonesia', 'hebatnya': 'hebat', 'bu': 'bu', 'da': 'da', 'gerakan': 'gera', 'nasional': 'nasional', 'literasi': 'literasi', 'digital': 'digital', 'talent': 'talent', 'scholarship': 'scholarship', 'leadership': 'leadership', 'academy': 'academy', 'program': 'program', 'kartu': 'kartu', 'prakerjalpsi': 'prakerjalpsi', 'indonesia': 'indonesia', 'indonesiajuara': 'indonesiajuara', 'indonesiahebatindonesiadamai': 'indonesiahebatindonesiadamai', 'keren': 'keren', 'bangetmas': 'bangetmas', 'memtri': 'memtri', 'merdeka': 'merdeka', 'belajarnyagindonesia': 'belajarnyagindonesia', 'presidensiindonesia': 'presidensiindonesia', 'konsumen': 'konsumen', 'industri': 'industri', 'rumah': 'rumah', 'tangga': 'tangga', 'diberdayakan': 'daya', 'koperasi': 'koperasi', 'lapor': 'lapor', 'bisanya': 'bisa', 'cewe': 'cewe', 'bego': 'bego', 'bencong': 'bencong', 'joget': 'joget', 'disuka': 'suka', 'mendingan': 'mending', 'doa': 'doa', 'perang': 'perang', 'yth': 'yth', 'perencana': 'rencana', 'core': 'core', 'values': 'values', 'gindonesiaakan': 'gindonesiaakan', 'keputusan': 'putus', 'diteriakin': 'diteriakin', 'event': 'event', 'ditonton': 'tonton', 'gila': 'gila', 'nari': 'nari', 'pikirin': 'pikirin', 'ancaman': 'ancam', 'lo': 'lo', 'bahas': 'bahas', 'ukraina': 'ukraina', 'formula': 'formula', 'urusan': 'urus', 'bang': 'bang', 'mending': 'mending', 'nonton': 'nonton', 'negara': 'negara', 'besara': 'besara', 'pro': 'pro', 'perdamaian': 'damai', 'kaya': 'kaya', 'org': 'org', 'indo': 'indo', 'mikir': 'mikir', 'kesel': 'kesel', 'gw': 'gw', 'isi': 'isi', 'twitter': 'twitter', 'menetapkan': 'tetap', 'kota': 'kota', 'bandung': 'bandung', 'jawa': 'jawa', 'barat': 'barat', 'lokasi': 'lokasi', 'penyelenggaraan': 'selenggara', 'pertemuan': 'temu', 'kelompok': 'kelompok', 'kerja': 'kerja', 'ngapain': 'ngapain', 'ngurusin': 'ngurusin', 'potensi': 'potensi', 'kekuatan': 'kuat', 'membangun': 'bangun', 'konkret': 'konkret', 'perusahaan': 'usaha', 'serikat': 'serikat', 'berkemban': 'kemban', 'berupaya': 'upaya', 'mewujudkan': 'wujud', 'transformasi': 'transformasi', 'negeri': 'negeri', 'memperjuangkannya': 'juang', 'berlangsungthe': 'berlangsungthe', 'sustainable': 'sustainable', 'finance': 'finance', 'private': 'private', 'sector': 'sector', 'roundtable': 'roundtable', 'xd': 'xd', 'forum': 'forum', 'berdiskusi': 'diskus', 'acara': 'acara', 'jg': 'jg', 'momentum': 'momentum', 'memperkuat': 'kuat', 'promosi': 'promosi', 'produk': 'produk', 'umkm': 'umkm', 'lokal': 'lokal', 'sejalan': 'jalan', 'agenda': 'agenda', 'inklusi': 'inklusi', 'keuangan': 'uang', 'pd': 'pd', 'presidensi': 'presidensi', 'alhamdulillah': 'alhamdulillah', 'presiden': 'presiden', 'elon': 'elon', 'musk': 'musk', 'hadir': 'hadir', 'november': 'november', 'anggota': 'anggota', 'menyerukan': 'seru', 'mungkinhal': 'mungkinhal', 'menkeusmi': 'menkeusmi', 'konferesi': 'konferesi', 'pers': 'pers', 'diada': 'ada', 'women': 'women', 'business': 'business', 'action': 'action', 'council': 'council', 'wibac': 'wibac', 'menggelar': 'gelar', 'bilateral': 'bilateral', 'menteri': 'menteri', 'ukm': 'ukm', 'republik': 'republik', 'rencana': 'rencana', 'renovasi': 'renovasi', 'kubah': 'kubah', 'gedung': 'gedung', 'dpr': 'dpr', 'streaming': 'streaming', 'jam': 'jam', 'kanal': 'kanal', 'youtube': 'youtube', 'bahlil': 'bahlil', 'terbaik': 'baik', 'rangka': 'rangka', 'konsepsi': 'konsepsi', 'gl': 'gl', 'berdasarkan': 'dasar', 'laporan': 'lapor', 'climate': 'climate', 'bonds': 'bonds', 'initiative': 'initiative', 'penerbitan': 'terbit', 'obligasi': 'obligasi', 'hijau': 'hijau', 'green': 'green', 'mencapai': 'capai', 'us': 'us', 'berita': 'berita', 'komitmen': 'komitmen', 'tunisia': 'tunisia', 'membuka': 'buka', 'peningkatan': 'tingkat', 'kerjasama': 'kerjasama', 'bidang': 'bidang', 'ekonomi': 'e ...
# ------------------------
# Pandas Apply:   0%|          | 0/207 [00:00<?, ?it/s]
# Hasil Stemming :
#                                                tweet  \
# 0   dan  jawaban nya min mainnakerpresidensiggind...
# 1  ayo siapa yang takut amerika rusia ketemuan di...
# 2  gerakan nasional literasi digital digital tale...
# 3  indonesia indonesiajuara indonesiahebatindones...
# 4  keren bangetmas memtri dengan program merdeka ...
#
#                                         tweet_tokens  \
# 0  [dan, jawaban, nya, min, mainnakerpresidensigg...
# 1  [ayo, siapa, yang, takut, amerika, rusia, kete...
# 2  [gerakan, nasional, literasi, digital, digital...
# 3  [indonesia, indonesiajuara, indonesiahebatindo...
# 4  [keren, bangetmas, memtri, dengan, program, me...
#
#                                     tweet_tokens_WSW  \
# 0  [min, mainnakerpresidensiggindonesiaewgindonesia]
# 1  [ayo, takut, amerika, rusia, ketemuan, bali, g...
# 2  [gerakan, nasional, literasi, digital, digital...
# 3  [indonesia, indonesiajuara, indonesiahebatindo...
# 4  [keren, bangetmas, memtri, program, merdeka, b...
#
#                                 tweet_tokens_stemmed
# 0  [min, mainnakerpresidensiggindonesiaewgindonesia]
# 1  [ayo, takut, amerika, rusia, ketemu, bal, gind...
# 2  [gera, nasional, literasi, digital, digital, t...
# 3  [indonesia, indonesiajuara, indonesiahebatindo...
# 4  [keren, bangetmas, memtri, program, merdeka, b...

# %%
TWEET_DATA.to_csv("D:/Kuliah Online/Pemrosesan Teks Praktik/PTP Project/Data/G20Indonesia_Preprocessing.csv")
TWEET_DATA['tweet_tokens'].to_csv("D:/Kuliah Online/Pemrosesan Teks Praktik/PTP Project/Data/G20Indonesia_Preprocessing_tweet_tokens.csv")
TWEET_DATA['tweet_tokens_WSW'].to_csv("D:/Kuliah Online/Pemrosesan Teks Praktik/PTP Project/Data/G20Indonesia_Preprocessing_tweet_tokens_WSW.csv")
TWEET_DATA['tweet_tokens_stemmed'].to_csv("D:/Kuliah Online/Pemrosesan Teks Praktik/PTP Project/Data/G20Indonesia_Preprocessing_tweet_tokens_stemmed.csv")
